# %% [markdown]
# <a href="https://colab.research.google.com/github/ResendeGabriela/SeedsOfChange/blob/main/Amazon_Deforestation_Analysing_States.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >> **Finding the Brazilian state that had the highest mean deforestation per km²**

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dbb6378b-6b66-44e5-80c6-7398827bb3e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbb6378b-6b66-44e5-80c6-7398827bb3e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
amazon = pd.read_csv(io.BytesIO(uploaded['Amazon - Sheet1 (1).csv']))

# %%
amazon.shape
# Out:
# (36, 9)

# %%
amazon.head(37)
# Out:
#       AC    AM   AP    MA     MT    PA    RO   RR    TO
# 0    620  1510   60  2450   5140  6990  2340  290  1650
# 1    540  1180  130  1420   5960  5750  1430  630   730
# 2    550   520  250  1100   4020  4890  1670  150   580
# 3    380   980  410   670   2840  3780  1110  420   440
# 4    400   799   36  1135   4674  3787  2265  281   409
# 5    482   370    0   372   6220  4284  2595  240   333
# 6    482   370    0   372   6220  4284  2595  240   333
# 7   1208  2114    9  1745  10391  7845  4730  220   797
# 8    433  1023    0  1061   6543  6135  2432  214   320
# 9    358   589   18   409   5271  4139  1986  184   273
# 10   536   670   30  1012   6466  5829  2041  223   576
# 11   441   720    0  1230   6963  5111  2358  220   216
# 12   547   612    0  1065   6369  6671  2465  253   244
# 13   419   634    7   958   7703  5237  2673  345   189
# 14   883   885    0  1085   7892  7510  3099   84   212
# 15  1078  1558   25   993  10405  7145  3597  439   156
# ...

# %%
analysis = amazon.describe() # The Output equals floats
analysis_int = analysis.astype(int) # The Output equals Integers
print(analysis_int)
# Out:
#          AC    AM   AP    MA     MT    PA    RO   RR    TO
# count    36    36   36    36     36    36    36   36    36
# mean    502   970   46   740   4282  4723  1860  263   244
# std     247   548   77   502   3053  1763  1000  129   317
# min     167   370    0   209    757  1741   435   84    23
# 25%     308   593   13   323   1591  3645  1129  180    49
# 50%     442   781   25   672   3639  4587  1640  235   140
# 75%     602  1193   40  1062   6393  5769  2440  300   323
# max    1208  2594  410  2450  11814  8870  4730  630  1650

# %%
mean = amazon.mean()
meanmax = mean.max() # Discover the highest mean
state = mean.idxmax() # Outputs the state with the highest mean
print("The highest mean value is: ", meanmax, " / From the state: ", state)
# Out:
# The highest mean value is:  4723.5  / From the state:  PA
